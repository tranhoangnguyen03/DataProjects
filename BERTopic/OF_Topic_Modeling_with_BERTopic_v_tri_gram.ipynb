# %% [markdown]
# <a href="https://colab.research.google.com/github/tranhoangnguyen03/DataProjects/blob/master/BERTopic/OF_Topic_Modeling_with_BERTopic_v_tri_gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instant Topic Modeling with BERTopic
#
# [More on BERTopic here](https://https://maartengr.github.io/BERTopic/index.html#:~:text=BERTopic%20is%20a%20topic%20modeling,supervised%2C%20and%20dynamic%20topic%20modeling.)

# %% [markdown]
# ### Preparation

# %%
#@title Setup & ingest dataset
import os, re, pickle

try:
    from bertopic import BERTopic
except:
    os.system('pip install bertopic')
    from bertopic import BERTopic

try:
    from stop_words import get_stop_words
except:
    os.system('pip install stop-words')
    from stop_words import get_stop_words
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('stopwords')


import pandas as pd 
import numpy as np
import warnings
warnings.simplefilter('ignore')

topics = list(set('''Excess
Excess
Swap
Price
In Store
Abandon
Site issues
Duplicate
Refusal to eat
Medical Reason
Medical Reason
Pet passed away
OOS
Reaction
Delivery Time'''.split('\n')))


url = 'https://raw.githubusercontent.com/joon-solutions/unsubscription_analysis/a87664fc6771fe641c260987dce2f17d868938b6/Example_Data_Pull_Subscription_Cancellation_Reasons_(Recharge).csv?token=GHSAT0AAAAAABSPDOHKZGR4P3AAWA2LNH4YYTBERLA'
df = pd.read_csv(url)
df = df[
        (~df.customer_email.str.contains('openfarmpet.com'))
        & (~df.cancelled_at.isnull())]
df['cancellation_reason_comments'] = (df
    .loc[:,['cancellation_reason','cancellation_reason_comments']]
    .apply(
            lambda x: x[0] if pd.isnull(x[1]) else x[1] 
        ,axis = 1
    )
    .str.replace('’',"'")
)
df.head(3)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#    subscription_id  customer_id               customer_email  address_id  \
# 0         42453790     28624583  kyle.gallant@diffagency.com    32221075
# 3         42684039     28765177        cberisoff@hotmail.com    32376373
# 4         42684040     28765174            cleorock@yahoo.ca    32376369
#
#       status               product_title variant_title  recurring_price  \
# 0  CANCELLED  Homestead Turkey & Chicken         4.5LB            28.49
# 3  CANCELLED     Homestead Turkey Recipe        13.5OZ            37.04
# 4  CANCELLED       Grass-Fed Beef Recipe        13.5OZ            37.04
#
#    price  quantity  ...  order_interval_unit  charge_day_of_month  \
# 0  28.49         1  ...                 week                  0.0
# 3    NaN         1  ...                 week                  NaN
# 4    NaN         2  ...                 week                  NaN
#
#   charge_day_of_week                                         properties  \
# 0                NaN  [{"name": "shipping_interval_frequency", "valu...
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#        cancelled_at                    cancellation_reason  \
# 0  2019-05-02 13:15                           Other reason
# 3  2019-09-20 13:18        I already have more than I need
# 4  2020-01-25 22:52  I want a different product or variety
#
#             cancellation_reason_comments        created_at  deleted_at  \
# 0                           Other reason  2019-05-02 13:12         NaN
# 3        I already have more than I need  2019-05-08 12:02         NaN
# 4  I want a different product or variety  2019-05-08 12:02         NaN
#
#          updated_at
# 0  2021-10-04 21:23
# 3  2020-09-16 16:48
# 4  2020-09-16 16:48
#
# [3 rows x 27 columns]

# %%
#@title Preprocess data & Training

lemmatizer = WordNetLemmatizer()
stop_words = list(get_stop_words('en'))         #About 900 stopwords
nltk_words = list(stopwords.words('english')) #About 150 stopwords
stop_words.extend(nltk_words)

contractions_dict = {"I've": 'I have', "ain't": "are not", "'s":" is", "aren't": "are not", "can't": "cannot", "can't've": "cannot have", "‘cause": "because", "could've": "could have", "couldn't": "could not", "couldn't've": "could not have", "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hadn't've": "had not have", "hasn't": "has not", "haven't": "have not", "he'd": "he would", "he'd've": "he would have", "he'll": "he will", "he'll've": "he will have", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have", "I'm": "I am", "I've": "I have", "isn't": "is not", "it'd": "it would", "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have", "let's": "let us", "ma'am": "madam", "mayn't": "may not", "might've": "might have", "mightn't": "might not", "mightn't've": "might not have", "must've": "must have", "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have", "o'clock": "of the clock", "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have", "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have", "that'd": "that would", "that'd've": "that would have", "there'd": "there would", "there'd've": "there would have", "they'd": "they would", "they'd've": "they would have","they'll": "they will",
 "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have", "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are", "we've": "we have", "weren't": "were not","what'll": "what will", "what'll've": "what will have", "what're": "what are", "what've": "what have", "when've": "when have", "where'd": "where did", "where've": "where have",
 "who'll": "who will", "who'll've": "who will have", "who've": "who have", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have", "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all", "y'all'd": "you all would", "y'all'd've": "you all would have", "y'all're": "you all are", "y'all've": "you all have", "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have", "you're": "you are", "you've": "you have"
 ,"ought to":"should"}

negatives_dict = {'are not':'not','am not':'not','is not':'not','was not':'not','were not':'not','have not':'not','has not':'not','had not'
    :'not','do not':'not','does not':'not','did not':'not','cannot':'not','can not':'not','could not':'not','should not':'not','ought not to':'not','shall not':'not','need not':'not','must not'
    :'not','might not':'not','may not':'not','maybe not':'not','will not':'not','would not':'not'}

class Prep:
    def expand_contractions(sentence, contractions_dict=contractions_dict):
        contractions_re = re.compile('(%s)'%'|'.join(contractions_dict.keys()))

        def replace(match):
            return contractions_dict[match.group(0)]
        return contractions_re.sub(replace, sentence)

    def transform_negatives(sentence, negatives_dict=negatives_dict):
        neg_re = re.compile('(%s)'%'|'.join(negatives_dict.keys()))

        def replace(match):
            return negatives_dict[match.group(0)]
        return neg_re.sub(replace, sentence)

    def remove_stop_words(sentence):
        words = sentence.split(' ')
        return ' '.join([word for word in words if word not in stop_words])

    def remove_punctuations(sentence):
        words = sentence.split(' ')
        return ' '.join([word for word in words if word.isalpha()])

    def lemmatize_all(sentence):
        words = sentence.split(' ')
        for word_type in ['n','v','a','r','s']:
            words = [lemmatizer.lemmatize(word, word_type) for word in words]
        return ' '.join(words)

class Model():
    def __init__(self, df):
        
        self.df = df
        self.model = BERTopic(top_n_words=10
            ,n_gram_range=(1,3)
            ,verbose=True
            ,nr_topics="auto")

    def save(self, filepath):
        with open(filepath, "wb") as f:
            pickle.dump(self, f)

    def load(self, filepath):
        with open(filepath, "rb") as f:
            pik = pickle.load(f)
        self.__dict__.update(pik.__dict__)
    
    def preprocess(self, df, comment_column):
        mask_invalid = df[comment_column].fillna('test').str.lower().str.contains('test')
        
        docs = (df[~mask_invalid][comment_column]
                .str.lower()
                .apply(Prep.expand_contractions)
                .apply(Prep.transform_negatives)
                .apply(Prep.remove_punctuations)
                .apply(Prep.lemmatize_all)
                #.apply(Prep.remove_stop_words)
                )
        return docs
        
    def train(self, comment_column='cancellation_reason_comments'):
        self.docs = self.preprocess(self.df, comment_column)
        sentences = self.docs.tolist()
        self.topics, self.probabilities = self.model.fit_transform(sentences)
        print(f'Training Result: {len(set(self.topics))} topics')
        
        topic_detail = {
            i : (v, [j[0] for j in self.model.get_topic(v)] ) 
                for i,v in enumerate(self.topics)
        }
        df_topics = pd.DataFrame.from_dict(topic_detail, orient='index').rename(columns={0:'Topic'})

        self.docs_transformed = df[[comment_column]].merge(
            pd.concat([self.docs.rename('Processed Comments').reset_index()
                ,df_topics['Topic']
                ,df_topics[1].apply(lambda x: ','.join(x)).str.split(',',expand=True)
                ],axis=1
            ).set_index('index')
            ,left_index=True,right_index=True
        )

    def predict(self, df, comment_column = 'cancellation_reason_comments'):
        df_ = self.preprocess(df, comment_column)
        sentences = df_.tolist()

        topics_int = self.model.transform(sentences)[0]
        topic_detail = {
            i : (v, [j[0] for j in self.model.get_topic(v)] ) 
                for i,v in enumerate(topics_int)
        }
        df_topics = pd.DataFrame.from_dict(topic_detail, orient='index').rename(columns={0:'Topic'})

        res = df[[comment_column]].merge(
            pd.concat([df_.rename('Processed Comments').reset_index()
                ,df_topics['Topic']
                ,df_topics[1].apply(lambda x: ','.join(x)).str.split(',',expand=True)
                ],axis=1
            ).set_index('index')
            ,left_index=True,right_index=True
        )
        
        return res

model = Model(df)
model.train()
# Out:
# Batches:   0%|          | 0/129 [00:00<?, ?it/s]
# 2022-04-21 08:34:49,454 - BERTopic - Transformed documents to Embeddings
# 2022-04-21 08:35:11,136 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-21 08:35:11,337 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2022-04-21 08:35:16,342 - BERTopic - Reduced number of topics from 88 to 48
# Training Result: 48 topics

# %% [markdown]
# ### Model Analysis

# %%
#@title Model Analysis
from google.colab import widgets

tabs_list = [
    'Topic Freq'
    ,'Topic Viz'
    ,'Topic BarChart'
    ,'Topic HeatMap'
    ,'Full df']
tabs = widgets.TabBar(tabs_list)

with tabs.output_to(tabs_list[0]):
    display(
        (model.model.get_topic_freq()
            .merge(
                pd.DataFrame.from_dict(
                    model.model.get_topics()
                    ,orient='index'
                    ).applymap(lambda x: x[0])
                ,left_on='Topic', right_index=True
            )
        )
    )

with tabs.output_to(tabs_list[1]):
    display(model.model.visualize_topics())

with tabs.output_to(tabs_list[2]):
    display(model.model.visualize_barchart(top_n_topics=len(set(model.topics))+1, n_words=10))

with tabs.output_to(tabs_list[3]):
    display(model.model.visualize_heatmap())

with tabs.output_to(tabs_list[4]):
    display(model.docs_transformed)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id31"></div>
#     Topic  Count                        0                     1  \
# 0       0    544             other reason                reason
# 1      -1    499                      the                    to
# 2       1    370           have more than             have more
# 3       2    339                      dog                   cat
# 4       3    289             subscription                 order
# 5       4    169           charge attempt         attempt reach
# 6       5    162                 long use           no long use
# 7       6    144                    store                 local
# 8       7    141                 accident    create by accident
# 9       8    132              this be too     expensive this be
# 10      9    129                 not need              need not
# 11     10    127     different product or            or variety
# 12     11    106                       je                dasdas
# 13     12     99            try different                   try
# 14     13     86                   change                  food
# 15     14     73                 long use           no long use
# 16     15     55                     ship                  move
# 17     16     40                  allergy                   dog
# 18     17     37  expensive too expensive         expensive too
# 19     18     36                   cancel              customer
# 20     19     34      duplicate duplicate             duplicate
# 21     20     33           flag to cancel               flag to
# 22     21     32                  website         website issue
# 23     22     31                     move              up again
# 24     23     27                    fraud           fraud fraud
# 25     24     26                   sooner             it sooner
# 26     25     25                 too much          too much too
# 27     26     24                      raw                to raw
# 28     27     24                 not want               want it
# 29     28     21                much food                  food
# 30     29     19                     pass             pass away
# 31     30     19             opt to order    order need instead
# 32     31     19                     open             open farm
# 33     32     18                  allergy       allergy allergy
# 34     33     18             too frequent              frequent
# 36     34     17                     card                credit
# 35     35     17             long time to           finish take
# 37     36     16                    delay         transit delay
# 38     37     15            website login  login and navigation
# 39     38     15                     bbhb                  zzzx
# 40     39     14                     pass              cat pass
# 41     40     13                    fussy       your product my
# 42     41     13                financial                afford
# 43     42     12                   salmon            the salmon
# 44     43     12                 to adult                 adult
# 45     44     11                 stop for       stop for awhile
# 46     45     11                long have          no long have
# 47     46     11                     same         same previous
#
#                                 2                      3  \
# 0                    reason other    reason other reason
# 1                             not                     be
# 2                       than need         more than need
# 3                              my                    not
# 4                              to                 modify
# 5                             max      of charge attempt
# 6                   long use this               use this
# 7                             buy                    pet
# 8                       create by            by accident
# 9              too expensive this         expensive this
# 10                  need not need                   need
# 11                     product or     product or variety
# 12                             na             abonnement
# 13                          brand            want to try
# 14                    food change            change food
# 15               use this product          long use this
# 16                          we be                address
# 17                       allergic                 dog ha
# 18              too expensive too              expensive
# 19             cancel by customer              cancel by
# 20  duplicate duplicate duplicate             duplicaton
# 21                           flag         to cancel flag
# 22                  issue website        website trouble
# 23                          again            again after
# 24                        combine      fraud fraud fraud
# 25                 need it sooner         sooner need it
# 26                       much too                   much
# 27                  switch to raw               raw food
# 28                    not want it            it not want
# 29                  too much food              food have
# 30                           away               dog pass
# 31                         opt to           need instead
# 32                           farm                  local
# 33                          trial          allergy trial
# 34               too frequent too           frequent too
# 36                    credit card                   miss
# 35                 take long time         time to finish
# 37                        transit  transit delay transit
# 38                      login and         and navigation
# 39                ssacad xxc xcxx            gvhg ssacad
# 40                      pass away                   away
# 41                   fussy dog no               eat your
# 42                          money               no money
# 43                         before                    the
# 44                  to adult food             adult food
# 45                     for awhile                 awhile
# 46                  long have dog               have dog
# 47                       previous     same previous same
#
#                            4                        5  \
# 0         other reason other                    other
# 1                        and                       my
# 2               already have                more than
# 3                       like                      the
# 4                        the                 to order
# 5                  of charge         number of charge
# 6                 product no          product no long
# 7                       shop                 in store
# 8                  wa create             wa create by
# 9           be too expensive                   be too
# 10              not need not                      not
# 11    want different product           want different
# 12          reaction je fais                       un
# 13       try different brand          different brand
# 14             change change                to change
# 15           this product no               product no
# 16                        we             ship address
# 17               be allergic                       ha
# 18             too expensive                      too
# 19               by customer                     skip
# 20  duplicate disc duplicate            duplicate sub
# 21            cancel flag to              cancel flag
# 22     website issue website              new website
# 23            up again after                    after
# 24           combine combine                     risk
# 25               sooner need           it sooner need
# 26                       too            much too much
# 27                 switch to            change to raw
# 28                      want              want it not
# 29                      much                 too much
# 30             dog pass away                 pet pass
# 31                       opt            to order need
# 32                        we                local pet
# 33             trial allergy  allergy allergy allergy
# 34     frequent too frequent                      too
# 36                   service           my credit card
# 35                   time to                take long
# 37             carrier delay                  carrier
# 38         website login and                    login
# 39                ssacad xxc             ccf ccc zzzx
# 40             cat pass away                      cat
# 41          eat your product                fussy dog
# 42            no long afford              can no long
# 43               salmon only                     once
# 44           switch to adult                   senior
# 45                      stop              awhile stop
# 46               have dog no                    puppy
# 47    previous same previous            previous same
#
#                                   6                         7  \
# 0              reason because other            reason because
# 1                                it                       for
# 2                 already have more                   already
# 3                              food                  not like
# 4                               not                      when
# 5              charge attempt reach             max number of
# 6                  use this product           this product no
# 7                           locally                        in
# 8                    this wa create          accident this wa
# 9                           this be             too expensive
# 10                          need no               not need it
# 11                  or variety want              variety want
# 12                         un essai                 reprendre
# 13                           to try          to try different
# 14                               to                    switch
# 15                  product no long                  use this
# 16                         move and                we be move
# 17                      dog allergy               allergic to
# 18                    right now too                   now too
# 19                 by customer care             customer care
# 20  duplicate duplicaton duplicaton      duplicate duplicaton
# 21                        to cancel                    cancel
# 22                          trouble                     up on
# 23                               up                   country
# 24          combine combine combine                fraud risk
# 25                          need it                        it
# 26                     too much for                  much for
# 27                        change to                      diet
# 28                    want not want                  want not
# 29                     of food have                  food too
# 30                      my dog pass                       dog
# 31                 need instead opt            instead opt to
# 32                    buy open farm                 farm from
# 33            allergy trial allergy       trial allergy trial
# 34                        too often                     often
# 36                        my credit                    no one
# 35                        long time                 to finish
# 37                    delay transit                ship delay
# 38                       navigation  navigation website login
# 39                  gvhg ssacad xxc                       ccc
# 40                      my cat pass                 away cara
# 41                      to eat your                  my fussy
# 42                           can no               long afford
# 43                            water                    rustic
# 44                            grain           isnt grain free
# 45                  awhile stop for           for awhile stop
# 46                           dog no             no long puppy
# 47                        same same         same previous see
#
#                           8                               9
# 0      because other reason            other reason because
# 1                       dog                    subscription
# 2                      than               need already have
# 3                       eat                         dog not
# 4                       new                       when need
# 5                max number                       reach max
# 6              this product                             use
# 7                 local pet                       pet store
# 8          by accident this                   accident this
# 9                 expensive                             too
# 10                long need                    no long need
# 11                  variety          variety want different
# 12          thank na dasdas                     reaction je
# 13                  want to                      brand want
# 14       change food change                  need to change
# 15             this product                             use
# 16              be move and                         be move
# 17              allergy and                  be allergic to
# 18                    right               now too expensive
# 19                     care                       to cancel
# 20  duplicate duplicate sub  duplicate duplicate duplicaton
# 21                       to
# 22          trouble website                      show up on
# 23                     will                          set up
# 24               to combine                 need to combine
# 25                     need                    need it need
# 26             too too much                         too too
# 27                   switch                     to raw food
# 28                   it not                             not
# 29            food too much                     lot of food
# 30            pet pass away                    pass away my
# 31              instead opt                      order need
# 32           open farm from                        buy open
# 33                 allergic                get allergy just
# 34                   to too                     enough room
# 36                    order                             and
# 35         finish take long                  to finish take
# 37      delay transit delay                carrier delay be
# 38       navigation website          and navigation website
# 39                     gvhg                        ccc zzzx
# 40           pass away cara                        away cat
# 41             my fussy dog                    long want to
# 42              no money no                afford financial
# 43                     down                            very
# 44         option that isnt                     option that
# 45                      for                         go away
# 46               long puppy                              no
# 47           same same same            see previous comment
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6c68e950-7b2c-4919-8e63-df3ef1bb8129" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c68e950-7b2c-4919-8e63-df3ef1bb8129")) {                    Plotly.newPlot(                        "6c68e950-7b2c-4919-8e63-df3ef1bb8129",                        [{"customdata":[[0,"other reason | reason | reason other | reason other reason | other reason other",544],[1,"have more than | have more | than need | more than need | already have",370],[2,"dog | cat | my | not | like",339],[3,"subscription | order | to | modify | the",289],[4,"charge attempt | attempt reach | max | of charge attempt | of charge",169],[5,"long use | no long use | long use this | use this | product no",162],[6,"store | local | buy | pet | shop",144],[7,"accident | create by accident | create by | by accident | wa create",141],[8,"this be too | expensive this be | too expensive this | expensive this | be too expensive",132],[9,"not need | need not | need not need | need | not need not",129],[10,"different product or | or variety | product or | product or variety | want different product",127],[11,"je | dasdas | na | abonnement | reaction je fais",106],[12,"try different | try | brand | want to try | try different brand",99],[13,"change | food | food change | change food | change change",86],[14,"long use | no long use | use this product | long use this | this product no",73],[15,"ship | move | we be | address | we",55],[16,"allergy | dog | allergic | dog ha | be allergic",40],[17,"expensive too expensive | expensive too | too expensive too | expensive | too expensive",37],[18,"cancel | customer | cancel by customer | cancel by | by customer",36],[19,"duplicate duplicate | duplicate | duplicate duplicate duplicate | duplicaton | duplicate disc duplicate",34],[20,"flag to cancel | flag to | flag | to cancel flag | cancel flag to",33],[21,"website | website issue | issue website | website trouble | website issue website",32],[22,"move | up again | again | again after | up again after",31],[23,"fraud | fraud fraud | combine | fraud fraud fraud | combine combine",27],[24,"sooner | it sooner | need it sooner | sooner need it | sooner need",26],[25,"too much | too much too | much too | much | too",25],[26,"raw | to raw | switch to raw | raw food | switch to",24],[27,"not want | want it | not want it | it not want | want",24],[28,"much food | food | too much food | food have | much",21],[29,"pass | pass away | away | dog pass | dog pass away",19],[30,"opt to order | order need instead | opt to | need instead | opt",19],[31,"open | open farm | farm | local | we",19],[32,"allergy | allergy allergy | trial | allergy trial | trial allergy",18],[33,"too frequent | frequent | too frequent too | frequent too | frequent too frequent",18],[34,"card | credit | credit card | miss | service",17],[35,"long time to | finish take | take long time | time to finish | time to",17],[36,"delay | transit delay | transit | transit delay transit | carrier delay",16],[37,"website login | login and navigation | login and | and navigation | website login and",15],[38,"bbhb | zzzx | ssacad xxc xcxx | gvhg ssacad | ssacad xxc",15],[39,"pass | cat pass | pass away | away | cat pass away",14],[40,"fussy | your product my | fussy dog no | eat your | eat your product",13],[41,"financial | afford | money | no money | no long afford",13],[42,"salmon | the salmon | before | the | salmon only",12],[43,"to adult | adult | to adult food | adult food | switch to adult",12],[44,"stop for | stop for awhile | for awhile | awhile | stop",11],[45,"long have | no long have | long have dog | have dog | have dog no",11],[46,"same | same previous | previous | same previous same | previous same previous",11]],"hovertemplate":"<b>T ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f6929af9-123c-4559-ba3e-2c78d2fbf603" class="plotly-graph-div" style="height:3000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f6929af9-123c-4559-ba3e-2c78d2fbf603")) {                    Plotly.newPlot(                        "f6929af9-123c-4559-ba3e-2c78d2fbf603",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.00807760541445318,0.009508404440495078,0.009905548555545584,0.010394604264424227,0.011395014621112113,0.011996768797628643,0.012204834811359179,0.012768074731832665,0.01600255740507485,0.018288512086820044],"y":["subscription  ","dog  ","for  ","it  ","my  ","and  ","be  ","not  ","to  ","the  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.09917012006672955,0.10048979395195416,0.1017420032223835,0.1039090516821898,0.1040746948475323,0.10412462368158991,0.10426173186442085,0.10426173186442085,0.10452641447356233,0.10480884130461092],"y":["need already have  ","than  ","already  ","already have more  ","more than  ","already have  ","more than need  ","than need  ","have more  ","have more than  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.016711395909641064,0.016932150352887324,0.016934012141409705,0.018242862858660693,0.01860306681809238,0.020061802336930997,0.020539138105825087,0.020610747949490055,0.02306781883312232,0.02307266913050057],"y":["dog not  ","eat  ","not like  ","food  ","the  ","like  ","not  ","my  ","cat  ","dog  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.010754831190179285,0.011957727562857486,0.012057403962829125,0.01222583697519481,0.012360387389014828,0.012554143707004072,0.013056042376939046,0.02235121913144564,0.037723922661662995,0.040728184852765324],"y":["when need  ","new  ","when  ","not  ","to order  ","the  ","modify  ","to  ","order  ","subscription  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.1288793014330521,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111,0.12934856115963111],"y":["reach max  ","max number  ","max number of  ","charge attempt reach  ","number of charge  ","of charge  ","of charge attempt  ","max  ","attempt reach  ","charge attempt  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.12599552934575994,0.12861001978555173,0.13189406171296586,0.1320061019192459,0.13249747257914438,0.13249747257914438,0.13366532225566743,0.13439766841501505,0.1347451890080641,0.1347451890080641],"y":["use  ","this product  ","this product no  ","use this product  ","product no long  ","product no  ","use this  ","long use this  ","no long use  ","long use  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.028638277139369554,0.03088887286506512,0.030924276885344746,0.03246274295902616,0.036803333412190144,0.0375617955412155,0.03772003748693164,0.0399674649436402,0.047211360496964935,0.07200140741514172],"y":["pet store  ","local pet  ","in  ","locally  ","in store  ","shop  ","pet  ","buy  ","local  ","store  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.1636262740030228,0.1636262740030228,0.1636262740030228,0.16592658919493888,0.16592658919493888,0.16592658919493888,0.16668746837691217,0.16668746837691217,0.16668746837691217,0.16668746837691217],"y":["accident this  ","by accident this  ","accident this wa  ","this wa create  ","wa create by  ","wa create  ","by accident  ","create by  ","create by accident  ","accident  "],"type":"bar","xaxis ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ae847966-2fec-4253-8988-c128757a11cb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae847966-2fec-4253-8988-c128757a11cb")) {                    Plotly.newPlot(                        "ae847966-2fec-4253-8988-c128757a11cb",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_the_to_not","0_other reason_reason_reaso...","1_have more than_have more_...","2_dog_cat_my","3_subscription_order_to","4_charge attempt_attempt re...","5_long use_no long use_long...","6_store_local_buy","7_accident_create by accide...","8_this be too_expensive thi...","9_not need_need not_need no...","10_different product or_or ...","11_je_dasdas_na","12_try different_try_brand","13_change_food_food change","14_long use_no long use_use...","15_ship_move_we be","16_allergy_dog_allergic","17_expensive too expensive_...","18_cancel_customer_cancel b...","19_duplicate duplicate_dupl...","20_flag to cancel_flag to_f...","21_website_website issue_is...","22_move_up again_again","23_fraud_fraud fraud_combine","24_sooner_it sooner_need it...","25_too much_too much too_mu...","26_raw_to raw_switch to raw","27_not want_want it_not wan...","28_much food_food_too much ...","29_pass_pass away_away","30_opt to order_order need ...","31_open_open farm_farm","32_allergy_allergy allergy_...","33_too frequent_frequent_to...","34_card_credit_credit card","35_long time to_finish take...","36_delay_transit delay_tran...","37_website login_login and ...","38_bbhb_zzzx_ssacad xxc xcxx","39_pass_cat pass_pass away","40_fussy_your product my_fu...","41_financial_afford_money","42_salmon_the salmon_before","43_to adult_adult_to adult ...","44_stop for_stop for awhile...","45_long have_no long have_l...","46_same_same previous_previ..."],"y":["-1_the_to_not","0_other reason_reason_reaso...","1_have more than_have more_...","2_dog_cat_my","3_subscription_order_to","4_charge attempt_attempt re...","5_long use_no long use_long...","6_store_local_buy","7_accident_create by accide...","8_this be too_expensive thi...","9_not need_need not_need no...","10_different product or_or ...","11_je_dasdas_na","12_try different_try_brand","13_change_food_food change","14_long use_no long use_use...","15_ship_move_we be","16_allergy_dog_allergic","17_expensive too expensive_...","18_cancel_customer_cancel b...","19_duplicate duplicate_dupl...","20_flag to cancel_flag to_f...","21_website_website issue_is...","22_move_up again_again","23_fraud_fraud fraud_combine","24_sooner_it sooner_need it...","25_too much_too much too_mu...","26_raw_to raw_switch to raw","27_not want_want it_not wan...","28_much food_food_too much ...","29_pass_pass away_away","30_opt to order_order need ...","31_open_open farm_farm","32_allergy_allergy allergy_...","33_too frequent_frequent_to...","34_card_credit_credit card","35_long time to_finish take...","36_delay_transit delay_tran...","37_website login_login and ...","38_bbhb_zzzx_ssacad xxc xcxx","39_pass_cat pass_pass away","40_fussy_your product my_fu...","41_financial_afford_money","42_salmon_the salmon_before","43_to adult_adult_to adult ...","44_stop for_stop for awhile...","45_long have_no long have_l...","46_same_same previous_previ..."],"z":[[0.9999999999999998,0.48080397302012035,0.5450856392957909,0.8482055150519255,0.8233706510810888,0.39104557029432085,0.48291066379731384,0.6201145641177468,0.4747078488706439,0.5588723445269452,0.4768448971147189,0.42373302095867804,0.5766835235128154,0.5178859825759696,0.5373850266473771,0.4827866070885669,0.59298684185247,0.43718211775948335,0.39213700026096476,0.5699581624209602,0.3671584533217491,0.37329540394083904,0.4203142251425013,0.6788012161054502,0.43494696268240773,0.4154755871778196,0.4550400273948481 ...
#                cancellation_reason_comments  \
# 0                              Other reason
# 3           I already have more than I need
# 4     I want a different product or variety
# 5           I already have more than I need
# 6                   I just placed an order.
# ...                                     ...
# 4152                                Reorder
# 4154    I'm purchasing from a store instead
# 4155  I'm opting to order as needed instead
# 4156                  This is too expensive
# 4157        I already have more than I need
#
#                          Processed Comments  Topic                     0  \
# 0                              other reason      0          other reason
# 3           i already have more than i need      1        have more than
# 4     i want a different product or variety     10  different product or
# 5           i already have more than i need      1        have more than
# 6                           i just place an      3          subscription
# ...                                     ...    ...                   ...
# 4152                                reorder      3          subscription
# 4154          purchase from a store instead      6                 store
# 4155            opt to order a need instead     30          opt to order
# 4156                  this be too expensive      8           this be too
# 4157        i already have more than i need      1        have more than
#
#                        1                   2                    3  \
# 0                 reason        reason other  reason other reason
# 3              have more           than need       more than need
# 4             or variety          product or   product or variety
# 5              have more           than need       more than need
# 6                  order                  to               modify
# ...                  ...                 ...                  ...
# 4152               order                  to               modify
# 4154               local                 buy                  pet
# 4155  order need instead              opt to         need instead
# 4156   expensive this be  too expensive this       expensive this
# 4157           have more           than need       more than need
#
#                            4               5                     6  \
# 0         other reason other           other  reason because other
# 3               already have       more than     already have more
# 4     want different product  want different       or variety want
# 5               already have       more than     already have more
# 6                        the        to order                   not
# ...                      ...             ...                   ...
# 4152                     the        to order                   not
# 4154                    shop        in store               locally
# 4155                     opt   to order need      need instead opt
# 4156        be too expensive          be too               this be
# 4157            already have       more than     already have more
#
#                    7                     8                       9
# 0     reason because  because other reason    other reason because
# 3            already                  than       need already have
# 4       variety want               variety  variety want different
# 5            already                  than       need already have
# 6               when                   new               when need
# ...              ...                   ...                     ...
# 4152            when                   new               when need
# 4154              in             local pet               pet store
# 4155  instead opt to           instead opt              order need
# 4156   too expensive             expensive                     too
# 4157         already                  than       need already have
#
# [4124 rows x 13 columns]

# %%
#@title Manual Test - Verbatim { vertical-output: true }
sentence = "i cannot afford it" #@param {type:"string"}
column = 'comment'

df_test = pd.DataFrame({column:sentence},index=[0])

df_res = model.predict(df_test, column)
similar_comments = model.docs_transformed.loc[
    model.docs_transformed['Topic']==df_res.Topic.iloc[0]
    ,model.docs_transformed.columns[0]
].unique()

from google.colab import widgets

tabs_list = [
    'Topic Result'
    ,'Similar Comments'
]
tabs = widgets.TabBar(tabs_list)

with tabs.output_to(tabs_list[0]):
    display(df_res)
with tabs.output_to(tabs_list[1]):
    display(similar_comments)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-04-21 09:03:29,868 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-21 09:03:29,870 - BERTopic - Predicted clusters with HDBSCAN
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id35"></div>
#               comment Processed Comments  Topic          0       1      2  \
# 0  i cannot afford it    i not afford it     41  financial  afford  money
#
#           3               4            5       6            7            8  \
# 0  no money  no long afford  can no long  can no  long afford  no money no
#
#                   9
# 0  afford financial
# array(['You have a great product, but can no longer afford it',
#        "Can't afford", 'Financial',
#        "Can't afford to spend 25$ more, will have to walk uphill across the city with it.",
#        'More money than I thought. As a topper it only lasts 2 weeks.',
#        'My financial status has very recently changed and I can no longer afford this.  My dogs LOVE the food.  Once my finances change I will be back!',
#        'can no longer afford', 'Financial instability', 'no money'],
#       dtype=object)

# %%
#@title Manual Test - Verbatim { run: "auto", vertical-output: true }
topic =  45#@param {type:"integer"}
column = 'comment'

similar_comments = (model.docs_transformed
    .loc[model.docs_transformed.Topic == topic
        ,model.docs_transformed.columns[0]
    ].unique()
)

from google.colab import widgets

tabs_list = [
    'Topic Result'
    ,'Similar Comments'
]
tabs = widgets.TabBar(tabs_list)

with tabs.output_to(tabs_list[0]):
    display(model.docs_transformed
        .loc[model.docs_transformed.Topic == topic
            ,model.docs_transformed.columns[2:]
        ].drop_duplicates()
    )
with tabs.output_to(tabs_list[1]):
    display(similar_comments)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id33"></div>
#      Topic          0             1              2         3            4  \
# 358     45  long have  no long have  long have dog  have dog  have dog no
#
#          5       6              7           8   9
# 358  puppy  dog no  no long puppy  long puppy  no
# array(['No longer have a dog',
#        'We no longer have a cat, he went missing a few weeks ago.',
#        'No longer have dog', 'no dog anymore',
#        'Changing foods. Pup not enjoying. ', 'No longer puppy',
#        'No longer a puppy',
#        'We were getting a puppy today but the adoption fell through ?',
#        'Older dog not a puppy'], dtype=object)
