# %% [markdown]
# <a href="https://colab.research.google.com/github/tranhoangnguyen03/DataProjects/blob/master/BERTopic/OF_Topic_Modeling_with_BERTopic_v_bi_gram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Instant Topic Modeling with BERTopic
#
# [More on BERTopic here](https://https://maartengr.github.io/BERTopic/index.html#:~:text=BERTopic%20is%20a%20topic%20modeling,supervised%2C%20and%20dynamic%20topic%20modeling.)

# %% [markdown]
# ### Preparation

# %%
#@title Setup & ingest dataset
import os

try:
    from bertopic import BERTopic
except:
    os.system('pip install bertopic')
    from bertopic import BERTopic

try:
    from stop_words import get_stop_words
except:
    os.system('pip install stop-words')
    from stop_words import get_stop_words
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('stopwords')


import pandas as pd 
import numpy as np

url = 'https://raw.githubusercontent.com/joon-solutions/unsubscription_analysis/master/Example_Data_Pull_Subscription_Cancellation_Reasons_(Recharge).csv?token=GHSAT0AAAAAABSPDOHLGYSGDQJE56MS3T64YSNQHOA'
df = pd.read_csv(url)
df.head(3)
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#    subscription_id  customer_id               customer_email  address_id  \
# 0         42453790     28624583  kyle.gallant@diffagency.com    32221075
# 1         42613662     28721717        megan@openfarmpet.com    32327967
# 2         42684037     28765173           blamondin@live.com    32376368
#
#       status               product_title variant_title  recurring_price  \
# 0  CANCELLED  Homestead Turkey & Chicken         4.5LB            28.49
# 1  CANCELLED               Senior Recipe         4.5LB            28.49
# 2  CANCELLED          Wild-Caught Salmon           8LB            51.29
#
#    price  quantity  ...  order_interval_unit  charge_day_of_month  \
# 0  28.49         1  ...                 week                  0.0
# 1  29.99         1  ...                 week                  0.0
# 2    NaN         3  ...                 week                  NaN
#
#   charge_day_of_week                                         properties  \
# 0                NaN  [{"name": "shipping_interval_frequency", "valu...
# 1                NaN  [{"name": "shipping_interval_frequency", "valu...
# 2                NaN                                                NaN
#
#        cancelled_at  cancellation_reason  cancellation_reason_comments  \
# 0  2019-05-02 13:15         Other reason                           NaN
# 1  2019-05-07 14:01         Other reason                          test
# 2               NaN                  NaN                           NaN
#
#          created_at  deleted_at        updated_at
# 0  2019-05-02 13:12         NaN  2021-10-04 21:23
# 1  2019-05-06 19:30         NaN  2020-09-16 16:44
# 2  2019-05-08 12:02         NaN  2020-09-16 16:52
#
# [3 rows x 27 columns]

# %%
#@title Preprocess data & Training

lemmatizer = WordNetLemmatizer()
stop_words = list(get_stop_words('en'))         #About 900 stopwords
nltk_words = list(stopwords.words('english')) #About 150 stopwords
stop_words.extend(nltk_words)

class Prep:
    def remove_stop_words(sentence):
        words = sentence.split(' ')
        return ' '.join([word for word in words if word not in stop_words])

    def remove_punctuations(sentence):
        words = sentence.split(' ')
        return ' '.join([word for word in words if word.isalpha()])

    def lemmatize_all(sentence):
        words = sentence.split(' ')
        for word_type in ['n','v','a','r','s']:
            words = [lemmatizer.lemmatize(word, word_type) for word in words]
        return ' '.join(words)

class Model():
    def __init__(self, df):
        
        self.df = df
        self.model = BERTopic(top_n_words=10
            ,n_gram_range=(1,3)
            ,verbose=True
            ,nr_topics="auto")

    
    def preprocess(self, df, comment_column):
        mask_invalid = df[comment_column].fillna('test').str.lower().str.contains('test')
        
        docs = (df[~mask_invalid][comment_column]
                .str.lower()
                .apply(Prep.remove_punctuations)
                .apply(Prep.lemmatize_all)
                #.apply(Prep.remove_stop_words)
                )
        return docs
        
    def train(self, comment_column='cancellation_reason_comments'):
        self.docs = self.preprocess(self.df, comment_column)
        sentences = self.docs.tolist()
        self.topics, self.probabilities = self.model.fit_transform(sentences)
        print(f'Training Result: {len(set(self.topics))} topics')
        
        topic_detail = {
            i : (v, [j[0] for j in self.model.get_topic(v)] ) 
                for i,v in enumerate(self.topics)
        }
        df_topics = pd.DataFrame.from_dict(topic_detail, orient='index').rename(columns={0:'Topic'})

        self.docs_transformed = df[[comment_column]].merge(
            pd.concat([self.docs.rename('Processed Comments').reset_index()
                ,df_topics['Topic']
                ,df_topics[1].apply(lambda x: ','.join(x)).str.split(',',expand=True)
                ],axis=1
            ).set_index('index')
            ,left_index=True,right_index=True
        )

    def predict(self, df, comment_column = 'cancellation_reason_comments'):
        df_ = self.preprocess(df, comment_column)
        sentences = df_.tolist()

        topics_int = self.model.transform(sentences)[0]
        topic_detail = {
            i : (v, [j[0] for j in self.model.get_topic(v)] ) 
                for i,v in enumerate(topics_int)
        }
        df_topics = pd.DataFrame.from_dict(topic_detail, orient='index').rename(columns={0:'Topic'})

        res = df[[comment_column]].merge(
            pd.concat([df_.rename('Processed Comments').reset_index()
                ,df_topics['Topic']
                ,df_topics[1].apply(lambda x: ','.join(x)).str.split(',',expand=True)
                ],axis=1
            ).set_index('index')
            ,left_index=True,right_index=True
        )
        
        return res

model = Model(df)
model.train()
# Out:
# Batches:   0%|          | 0/37 [00:00<?, ?it/s]
# 2022-04-06 11:06:26,969 - BERTopic - Transformed documents to Embeddings
# 2022-04-06 11:06:34,942 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-06 11:06:35,017 - BERTopic - Clustered UMAP embeddings with HDBSCAN
# 2022-04-06 11:06:37,072 - BERTopic - Reduced number of topics from 36 to 31
# Training Result: 31 topics

# %% [markdown]
# ### Model Analysis

# %%
#@title Model Analysis
from google.colab import widgets

tabs_list = [
    'Topic Freq'
    ,'Topic Viz'
    ,'Topic BarChart'
    ,'Topic HeatMap'
    ,'Full df']
tabs = widgets.TabBar(tabs_list)

with tabs.output_to(tabs_list[0]):
    display(
        (model.model.get_topic_freq()
            .merge(
                pd.DataFrame.from_dict(
                    model.model.get_topics()
                    ,orient='index'
                    ).applymap(lambda x: x[0])
                ,left_on='Topic', right_index=True
            )
        )
    )

with tabs.output_to(tabs_list[1]):
    display(model.model.visualize_topics())

with tabs.output_to(tabs_list[2]):
    display(model.model.visualize_barchart(top_n_topics=len(set(model.topics))+1, n_words=10))

with tabs.output_to(tabs_list[3]):
    display(model.model.visualize_heatmap())

with tabs.output_to(tabs_list[4]):
    display(model.docs_transformed)
# Out:
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id7"></div>
#     Topic  Count               0                   1                      2  \
# 0       0    215             cat                  my                    dog
# 1      -1    207             the                  to                     be
# 2       1     71             too         because too            too confuse
# 3       2     69    subscription                 the                     to
# 4       3     49           order            to order          want to order
# 5       4     38         locally               store           your product
# 6       5     38             raw                food                 switch
# 7       6     36             pet           local pet                  local
# 8       7     35        in store                shop                shop in
# 9       8     33           delay                ship                   post
# 10      9     33             too                have                   much
# 11     10     33  flag to cancel             flag to                   flag
# 12     11     31         allergy                 dog                     ha
# 13     12     31           error                  to               an error
# 14     13     24        previous       same previous              duplicate
# 15     14     23           fraud         fraud fraud      fraud fraud fraud
# 16     15     17           fussy                 eat           no long want
# 17     16     17      navigation      and navigation          website login
# 18     17     16            move             be move                  we be
# 19     18     16          cancel        subscription    cancel subscription
# 20     19     16         website       issue website  website issue website
# 21     20     15        customer  cancel by customer              cancel by
# 22     21     15            pass           pass away                   away
# 23     22     15         allergy     allergy allergy                  trial
# 24     23     14         no long                  no                   long
# 25     24     14            move            my email            to my email
# 26     25     14         need it                need           just need it
# 27     26     13            ship                have                   case
# 28     27     12            open                farm              open farm
# 29     28     11        stop for     stop for awhile             for awhile
# 30     29     10      freeze dry              freeze           subscription
#
#                                    3                           4  \
# 0                                eat                      my cat
# 1                                for                         and
# 2                    too because too                 too because
# 3                                bag                         and
# 4                               when                        want
# 5                            product                        find
# 6                             to raw                   switch to
# 7                          pet store                       store
# 8                      shop in store                       store
# 9                             canada                    too long
# 10                    have more than                   have more
# 11                    to cancel flag              cancel flag to
# 12                            dog ha                    allergic
# 13                               add                          an
# 14            previous same previous          same previous same
# 15                              risk                   financial
# 16                      my fussy dog                    eat your
# 17                 website login and        login and navigation
# 18                              will                       again
# 19  subscription cancel subscription  cancel subscription cancel
# 20                     website issue             website trouble
# 21                       by customer                      cancel
# 22                       my dog pass               dog pass away
# 23           allergy allergy allergy               allergy trial
# 24                       no long use                    long use
# 25                      my email for                 reply to my
# 26                            it yet                 need it yet
# 27                           company        to different company
# 28                     buy open farm                    supplier
# 29                            awhile                        stop
# 30                     freeze dry so                      dry so
#
#                       5                        6                         7  \
# 0                  food                     like                       the
# 1                   dog                       my                      food
# 2        no too confuse                   no too           too confuse too
# 3                    of         the subscription                      from
# 4             when need                  want to                order when
# 5                  sell                that sell                     local
# 6                  diet            switch to raw                    change
# 7       local pet store                      buy              my local pet
# 8                    in               to shop in                   to shop
# 9           canada post                      too                   transit
# 10             too much                more than                 much have
# 11          cancel flag                to cancel                    cancel
# 12          allergy and               allergy to                ha allergy
# 13                  try                    go to                    create
# 14        previous same                     same       duplicate duplicate
# 15           fraud risk               fraudulent                risk fraud
# 16     eat your product                fussy dog              fussy dog no
# 17            login and                    login  navigation website login
# 18                   be                 move and                again once
# 19  subscription cancel                       to                       yet
# 20      trouble website  website trouble website                   trouble
# 21                   by         by customer care             customer care
# 22             dog pass                      dog                    my dog
# 23  trial allergy trial            trial allergy     allergy trial allergy
# 24                  use             this no long                   this no
# 25            email for                 reply to               no reply to
# 26            just need                      yet                        it
# 27      move their food     different company or              food over to
# 28      farm from local                farm from               to buy open
# 29          awhile stop          awhile stop for           for awhile stop
# 30                  dry                      the                        of
#
#                                 8                       9
# 0                             not                      be
# 1                              it                    have
# 2                     gvhg no too                 gvhg no
# 3                              my                      be
# 4                            need                      to
# 5                            your                   carry
# 6                        raw food                      to
# 7                              at                my local
# 8               purchase in store             purchase in
# 9                   transit delay             post office
# 10                           than               expensive
# 11                             to
# 12                 dog ha allergy           ha allergy to
# 13                     product to                      so
# 14  duplicate duplicate duplicate           duplicate not
# 15                risk fraud risk        fraud risk fraud
# 16                    to eat your               long want
# 17             navigation website  and navigation website
# 18                    be move and                      we
# 19                           have                     the
# 20                          issue     issue website issue
# 21                           care    customer care cancel
# 22                      away last          pass away last
# 23                 until they get            get just get
# 24                    use this no           long use this
# 25                          reply                no reply
# 26                  yet just need             it yet just
# 27                      food over      ship probably move
# 28                 open farm from                buy open
# 29                            for                   thank
# 30                my subscription         friendly option
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e814da8d-5cc4-4bcf-8a90-56d767027f0e" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e814da8d-5cc4-4bcf-8a90-56d767027f0e")) {                    Plotly.newPlot(                        "e814da8d-5cc4-4bcf-8a90-56d767027f0e",                        [{"customdata":[[0,"cat | my | dog | eat | my cat",215],[1,"too | because too | too confuse | too because too | too because",71],[2,"subscription | the | to | bag | and",69],[3,"order | to order | want to order | when | want",49],[4,"locally | store | your product | product | find",38],[5,"raw | food | switch | to raw | switch to",38],[6,"pet | local pet | local | pet store | store",36],[7,"in store | shop | shop in | shop in store | store",35],[8,"delay | ship | post | canada | too long",33],[9,"too | have | much | have more than | have more",33],[10,"flag to cancel | flag to | flag | to cancel flag | cancel flag to",33],[11,"allergy | dog | ha | dog ha | allergic",31],[12,"error | to | an error | add | an",31],[13,"previous | same previous | duplicate | previous same previous | same previous same",24],[14,"fraud | fraud fraud | fraud fraud fraud | risk | financial",23],[15,"fussy | eat | no long want | my fussy dog | eat your",17],[16,"navigation | and navigation | website login | website login and | login and navigation",17],[17,"move | be move | we be | will | again",16],[18,"cancel | subscription | cancel subscription | subscription cancel subscription | cancel subscription cancel",16],[19,"website | issue website | website issue website | website issue | website trouble",16],[20,"customer | cancel by customer | cancel by | by customer | cancel",15],[21,"pass | pass away | away | my dog pass | dog pass away",15],[22,"allergy | allergy allergy | trial | allergy allergy allergy | allergy trial",15],[23,"no long | no | long | no long use | long use",14],[24,"move | my email | to my email | my email for | reply to my",14],[25,"need it | need | just need it | it yet | need it yet",14],[26,"ship | have | case | company | to different company",13],[27,"open | farm | open farm | buy open farm | supplier",12],[28,"stop for | stop for awhile | for awhile | awhile | stop",11],[29,"freeze dry | freeze | subscription | freeze dry so | dry so",10]],"hovertemplate":"<b>Topic %{customdata[0]}</b><br>Words: %{customdata[1]}<br>Size: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[215,71,69,49,38,38,36,35,33,33,33,31,31,24,23,17,17,16,16,16,15,15,15,14,14,14,13,12,11,10],"sizemode":"area","sizeref":0.134375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.9389081597328186,-0.42920127511024475,4.3763251304626465,-9.668684005737305,-8.672558784484863,-2.846517562866211,-8.84476375579834,-8.266683578491211,-3.15785551071167,9.754904747009277,10.355321884155273,0.5352279543876648,4.586027145385742,10.771245956420898,4.194506645202637,0.1830022782087326,2.6440846920013428,-8.882193565368652,-9.499367713928223,2.7250943183898926,10.419313430786133,10.67768383026123,4.757327556610107,-0.22264328598976135,9.484634399414062,9.768210411071777,-3.062840700149536,-9.087420463562012,9.627017974853516,4.250189781188965],"xaxis":"x","y":[-5.974179267883301,-6.041579246520996,-2.2501659393310547,-2.0816922187805176,-0.4472033977508545,7.089264869689941,-0.8721472024917603,-0.35684725642204285,6.778828144073486,6.522390365600586,6.140685558319092,-5.75659704208374,-2.0105795860290527,6.2459282875061035,-1.5823173522949219,-5.7643232345581055,5.402669906616211,-0.2025042474269867,-1.895372986793518,5.321922779083252,6.515784740447998,6.6885199546813965,-2.057492256164551,-5.887884140014648,7.07258939743042,6.7622981 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d74b86fc-38e9-4d16-b2a9-b3e4573dab39" class="plotly-graph-div" style="height:2000px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d74b86fc-38e9-4d16-b2a9-b3e4573dab39")) {                    Plotly.newPlot(                        "d74b86fc-38e9-4d16-b2a9-b3e4573dab39",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.01070108579991269,0.011011219697604395,0.011405224326855428,0.011572561308507425,0.012250361322699058,0.012667323650904595,0.013563267055078536,0.014990342300784347,0.015577254379432224,0.017190107923898298],"y":["have  ","it  ","food  ","my  ","dog  ","and  ","for  ","be  ","to  ","the  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.39123812066331903,0.47316601576302136],"y":["gvhg no  ","gvhg no too  ","too confuse too  ","no too  ","no too confuse  ","too because  ","too because too  ","too confuse  ","because too  ","too  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.012547807685279602,0.012556331303302594,0.012947818207838394,0.01310656204409247,0.014294050509814589,0.01509245821043666,0.015258794177277218,0.022770466154073587,0.023333233621602775,0.03855251604877653],"y":["be  ","my  ","from  ","the subscription  ","of  ","and  ","bag  ","to  ","the  ","subscription  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.03607967007000846,0.03741695106779489,0.03794354067581323,0.04242936978298857,0.043868735989939255,0.046115246741264895,0.047746472599352545,0.051783324311770296,0.05260841909998006,0.09416615946493856],"y":["to  ","need  ","order when  ","want to  ","when need  ","want  ","when  ","want to order  ","to order  ","order  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.040355468750058604,0.04123054135817934,0.04354877163876924,0.04473533500376926,0.04539990234381594,0.04688539171539376,0.050745281671605344,0.05384090569539168,0.06279483090366872,0.07398520897020094],"y":["carry  ","your  ","local  ","that sell  ","sell  ","find  ","product  ","your product  ","store  ","locally  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.03868391693220456,0.04068267202792649,0.04486411869501906,0.05028600773799713,0.05216533199860616,0.05899794481898698,0.06679082546798576,0.067002061877419,0.06878507942239784,0.09072147098166734],"y":["to  ","raw food  ","change  ","switch to raw  ","diet  ","switch to  ","to raw  ","switch  ","food  ","raw  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.02456042506723997,0.026093926162855663,0.027226021088315486,0.030504467478121522,0.031156985355059,0.036397208695828465,0.036991140404544307,0.050799095805869,0.05166003618320477,0.0599727030772974],"y":["my local  ","at  ","my local pet  ","buy  ","local pet store  ","store  ","pet store  ","local  ","local pet  ","pet  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.06037404819292287,0.06037404819292287,0.09007788901711822,0.0936397914649904,0.1263516611879298,0.13519732401660542,0.14792894285686603,0.1541532942932207,0.16781249748217186,0.1887530901999825],"y":["purchase in  ","purchase in store  ","to shop  ","to shop in  ","in  ","store  ","shop in store  ","shop in  ","shop  ","in store  "],"type":"bar","xaxis":"x8","yaxis":"y8"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.02596150269553683,0.02596150269553683,0.0259615026955368 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a764caa8-381b-47b0-b436-21603728a119" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a764caa8-381b-47b0-b436-21603728a119")) {                    Plotly.newPlot(                        "a764caa8-381b-47b0-b436-21603728a119",                        [{"coloraxis":"coloraxis","name":"0","x":["-1_the_to_be","0_cat_my_dog","1_too_because too_too confuse","2_subscription_the_to","3_order_to order_want to or...","4_locally_store_your product","5_raw_food_switch","6_pet_local pet_local","7_in store_shop_shop in","8_delay_ship_post","9_too_have_much","10_flag to cancel_flag to_f...","11_allergy_dog_ha","12_error_to_an error","13_previous_same previous_d...","14_fraud_fraud fraud_fraud ...","15_fussy_eat_no long want","16_navigation_and navigatio...","17_move_be move_we be","18_cancel_subscription_canc...","19_website_issue website_we...","20_customer_cancel by custo...","21_pass_pass away_away","22_allergy_allergy allergy_...","23_no long_no_long","24_move_my email_to my email","25_need it_need_just need it","26_ship_have_case","27_open_farm_open farm","28_stop for_stop for awhile...","29_freeze dry_freeze_subscr..."],"y":["-1_the_to_be","0_cat_my_dog","1_too_because too_too confuse","2_subscription_the_to","3_order_to order_want to or...","4_locally_store_your product","5_raw_food_switch","6_pet_local pet_local","7_in store_shop_shop in","8_delay_ship_post","9_too_have_much","10_flag to cancel_flag to_f...","11_allergy_dog_ha","12_error_to_an error","13_previous_same previous_d...","14_fraud_fraud fraud_fraud ...","15_fussy_eat_no long want","16_navigation_and navigatio...","17_move_be move_we be","18_cancel_subscription_canc...","19_website_issue website_we...","20_customer_cancel by custo...","21_pass_pass away_away","22_allergy_allergy allergy_...","23_no long_no_long","24_move_my email_to my email","25_need it_need_just need it","26_ship_have_case","27_open_farm_open farm","28_stop for_stop for awhile...","29_freeze dry_freeze_subscr..."],"z":[[0.9999999999999996,0.8783506892768413,0.43736725438322377,0.8881266125912051,0.6564368038360779,0.7243266769193064,0.6532009634082205,0.5855460600922159,0.5043740761292876,0.642874870522578,0.6623607263329946,0.36922037551387893,0.4379254773132074,0.7599944189940181,0.47837713516764013,0.3133606019474685,0.6248516395593475,0.29235871434783556,0.6788167699654486,0.5087308206834065,0.305709242122989,0.5458771791501839,0.555525150684645,0.2307141030143787,0.566704337140303,0.5851652972916096,0.5080232091786444,0.6985802899453262,0.4210210778305765,0.5721205434289969,0.6732889856055244],[0.8783506892768413,1.0000000000000002,0.3886430490139837,0.7546096963163991,0.5854315181791784,0.6759489253777644,0.6475821305394,0.6676771283293453,0.4701572836089555,0.5876039680961039,0.5630159174683071,0.3321699039257338,0.49152825303940695,0.6503733439111874,0.4563946346695178,0.3078504269902227,0.7271392731018173,0.26211617335516396,0.5939025261398607,0.4144554038761329,0.2831483680005225,0.4922617758573325,0.5899074243008959,0.23140888559362605,0.5449851150622431,0.5370071493473976,0.4272971671966287,0.6575413119927738,0.4151306195084733,0.4920415718562679,0.6294558526164467],[0.43736725438322377,0.3886430490139837,1.0,0.41711220473072586,0.31454355208467394,0.3784416863886634,0.36973040327010853,0.2409742599307232,0.22524729228859322,0.3989280963422221,0.5602828182743144,0.20254412742324707,0.23547494116767215,0.35189905018191214,0.34473819020789503,0.22874724061338897,0.33582917194284123,0.11845558932548367,0.3918517126848997,0.28550083914597424,0.0771582494833814,0.29021743806559275,0.2662089175474524,0.15478641832205825,0.4121345853727456,0.29975398594207237,0.32190228897569206,0.3525343833074444,0.25210057 ...
#                            cancellation_reason_comments  \
# 6                               I just placed an order.
# 7                                      Vet Diet Change
# 10    I cancelled this subscription over a month ago...
# 16    delivery issues (e.g., item held at post offic...
# 18                                  purchasing in store
# ...                                                 ...
# 4106                      Cats do not enjoy the recipes
# 4115                                  Merging under one
# 4119                        Shopping in store instead.
# 4125                                       Diet Change
# 4134                                         Navigation
#
#                                      Processed Comments  Topic           0  \
# 6                                       i just place an      3       order
# 7                                       vet diet change     -1         the
# 10    i cancel this subscription over a month ago th...     18      cancel
# 16    delivery issue item hold at post office instea...      8       delay
# 18                                    purchase in store      7    in store
# ...                                                 ...    ...         ...
# 4106                        cat do not enjoy the recipe      0         cat
# 4115                                    merge under one     -1         the
# 4119                                      shop in store      7    in store
# 4125                                        diet change      5         raw
# 4134                                         navigation     16  navigation
#
#                    1                    2                                 3  \
# 6           to order        want to order                              when
# 7                 to                   be                               for
# 10      subscription  cancel subscription  subscription cancel subscription
# 16              ship                 post                            canada
# 18              shop              shop in                     shop in store
# ...              ...                  ...                               ...
# 4106              my                  dog                               eat
# 4115              to                   be                               for
# 4119            shop              shop in                     shop in store
# 4125            food               switch                            to raw
# 4134  and navigation        website login                 website login and
#
#                                4                    5              6  \
# 6                           want            when need        want to
# 7                            and                  dog             my
# 10    cancel subscription cancel  subscription cancel             to
# 16                      too long          canada post            too
# 18                         store                   in     to shop in
# ...                          ...                  ...            ...
# 4106                      my cat                 food           like
# 4115                         and                  dog             my
# 4119                       store                   in     to shop in
# 4125                   switch to                 diet  switch to raw
# 4134        login and navigation            login and          login
#
#                              7                   8                       9
# 6                   order when                need                      to
# 7                         food                  it                    have
# 10                         yet                have                     the
# 16                     transit       transit delay             post office
# 18                     to shop   purchase in store             purchase in
# ...                        ...                 ...                     ...
# 4106                       the                 not                      be
# 4115                      food                  it                    have
# 4119                   to shop   purchase in store             purchase in
# 4125                    change            raw food                      to
# 4134  navigation website login  navigation website  and navigation website
#
# [1181 rows x 13 columns]

# %%
#@title Manual Test
sentence = "I've switch to shop nearby" #@param {type:"string"}
column = 'comment'

df_test = pd.DataFrame({column:sentence},index=[0])

df_res = model.predict(df_test, column)
similar_comments = model.docs_transformed.loc[
    model.docs_transformed['Topic']==df_res.Topic.iloc[0]
    ,model.docs_transformed.columns[0]
].unique()

from google.colab import widgets

tabs_list = [
    'Topic Result'
    ,'Similar Comments'
]
tabs = widgets.TabBar(tabs_list)

with tabs.output_to(tabs_list[0]):
    display(df_res)
with tabs.output_to(tabs_list[1]):
    display(similar_comments)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-04-06 11:08:19,561 - BERTopic - Reduced dimensionality with UMAP
# 2022-04-06 11:08:19,564 - BERTopic - Predicted clusters with HDBSCAN
# <link rel=stylesheet type=text/css href='/nbextensions/google.colab/tabbar.css'></link>
# <script src='/nbextensions/google.colab/tabbar_main.min.js'></script>
# <div id="id8"></div>
#                       comment     Processed Comments  Topic         0     1  \
# 0  I've switch to shop nearby  switch to shop nearby      7  in store  shop
#
#          2              3      4   5           6        7                  8  \
# 0  shop in  shop in store  store  in  to shop in  to shop  purchase in store
#
#              9
# 0  purchase in
# array(['purchasing in store', 'Buying locally.',
#        'I can buy this for less in store',
#        'Wants to shop in store instead. ', 'This is now sold in store.',
#        'will be switching to purchasing in store locally',
#        'easier to purchase it in store',
#        'Wishes to shop in store instead', 'shop in store',
#        'Prefers shopping instore ', 'Shopping in store',
#        'I moved to a new location where I can purchase in store now!',
#        "I can shop in store at Ren's and no longer need the mailed to me",
#        'Wants to purchase in store because of website ', 'Shops in Store',
#        'Buying in store', 'wishes to purchase in store as well.',
#        'Wish to shop in store instead. ', 'Buying fresh food.',
#        'Wants to shop in store instead', 'Will shop instore instead ',
#        'Shop in store', 'Shopping in Store',
#        'Wants to shop in store. Delivery is unreliable. ',
#        'Shopping in store instead. '], dtype=object)
